# %% [markdown]
# **U- Net Model**

# %%
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPool2D, UpSampling2D, Concatenate, Add
import tensorflow as tf
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"


def conv_block(inputs, out_ch, rate=1):
    """

    With "same" padding, the necessary amount of zero-padding is added to the input so that the output has the same height and width as the input.

    """
    x = Conv2D(out_ch, 3, padding="same", dilation_rate=1)(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    return x


def RSU_L(inputs, out_ch, int_ch, num_layers, rate=2):
    """
    inputs: This is the input tensor or layer to the function. It represents the input feature map on which the operations will be performed.

    out_ch: It stands for "output channels." This is the number of filters or channels that the convolutional layers in the function will produce. It determines the depth of the output feature map.

    int_ch: It stands for "intermediate channels." This is the number of channels used in the intermediate convolutional layers of the function. It can be considered as a bottleneck layer.

    num_layers: This parameter represents the number of layers in the encoding part of the network. It determines how many times the function will apply downsampling operations (MaxPooling) followed by convolutional layers on the input.

    rate=2: This is a default parameter for the dilation rate. Dilation rate controls the spacing between the kernel points, influencing the field of view of each point. A dilation rate of 1 corresponds to standard convolution, and a rate of 2 or more introduces spaces between the kernel points.

    """

    """ Initial Conv """
    x = conv_block(inputs, out_ch)
    init_feats = x

    """ Encoder """
    """
    skip is to keep a record of the intermediate feature maps obtained after each convolutional block in the encoding part of the network. These feature maps will be used during the decoding part, where the network has to concatenate or skip connections between the corresponding feature maps from the encoding and decoding stages. This skip connection helps in retaining and utilizing low-level details during the upsampling process.
    """
    skip = []
    x = conv_block(x, int_ch)
    skip.append(x)

    for i in range(num_layers-2):
        x = MaxPool2D((2, 2))(x)
        x = conv_block(x, int_ch)
        skip.append(x)

    """ Bridge """
    x = conv_block(x, int_ch, rate=rate)

    """ Decoder """
    skip.reverse()

    x = Concatenate()([x, skip[0]])
    x = conv_block(x, int_ch)

    for i in range(num_layers-3):
        x = UpSampling2D(size=(2, 2), interpolation="bilinear")(x)
        x = Concatenate()([x, skip[i+1]])
        x = conv_block(x, int_ch)

    x = UpSampling2D(size=(2, 2), interpolation="bilinear")(x)
    x = Concatenate()([x, skip[-1]])
    x = conv_block(x, out_ch)

    """ Add """
    x = Add()([x, init_feats])
    return x


def RSU_4F(inputs, out_ch, int_ch):
    """ Initial Conv """
    x0 = conv_block(inputs, out_ch, rate=1)

    """ Encoder """
    x1 = conv_block(x0, int_ch, rate=1)
    x2 = conv_block(x1, int_ch, rate=2)
    x3 = conv_block(x2, int_ch, rate=4)

    """ Bridge """
    x4 = conv_block(x3, int_ch, rate=8)

    """ Decoder """
    x = Concatenate()([x4, x3])
    x = conv_block(x, int_ch, rate=4)

    x = Concatenate()([x, x2])
    x = conv_block(x, int_ch, rate=2)

    x = Concatenate()([x, x1])
    x = conv_block(x, out_ch, rate=1)

    """ Addition """
    x = Add()([x, x0])
    return x


def u2net(input_shape, out_ch, int_ch, num_classes=1):
    """ Input Layer """
    inputs = Input(input_shape)
    s0 = inputs

    """ Encoder """
    s1 = RSU_L(s0, out_ch[0], int_ch[0], 7)
    p1 = MaxPool2D((2, 2))(s1)

    s2 = RSU_L(p1, out_ch[1], int_ch[1], 6)
    p2 = MaxPool2D((2, 2))(s2)

    s3 = RSU_L(p2, out_ch[2], int_ch[2], 5)
    p3 = MaxPool2D((2, 2))(s3)

    s4 = RSU_L(p3, out_ch[3], int_ch[3], 4)
    p4 = MaxPool2D((2, 2))(s4)

    s5 = RSU_4F(p4, out_ch[4], int_ch[4])
    p5 = MaxPool2D((2, 2))(s5)

    """ Bridge """
    b1 = RSU_4F(p5, out_ch[5], int_ch[5])
    b2 = UpSampling2D(size=(2, 2), interpolation="bilinear")(b1)

    """ Decoder """
    d1 = Concatenate()([b2, s5])
    d1 = RSU_4F(d1, out_ch[6], int_ch[6])
    u1 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d1)

    d2 = Concatenate()([u1, s4])
    d2 = RSU_L(d2, out_ch[7], int_ch[7], 4)
    u2 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d2)

    d3 = Concatenate()([u2, s3])
    d3 = RSU_L(d3, out_ch[8], int_ch[8], 5)
    u3 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d3)

    d4 = Concatenate()([u3, s2])
    d4 = RSU_L(d4, out_ch[9], int_ch[9], 6)
    u4 = UpSampling2D(size=(2, 2), interpolation="bilinear")(d4)

    d5 = Concatenate()([u4, s1])
    d5 = RSU_L(d5, out_ch[10], int_ch[10], 7)

    """ Side Outputs """
    y1 = Conv2D(num_classes, 3, padding="same")(d5)

    y2 = Conv2D(num_classes, 3, padding="same")(d4)
    y2 = UpSampling2D(size=(2, 2), interpolation="bilinear")(y2)

    y3 = Conv2D(num_classes, 3, padding="same")(d3)
    y3 = UpSampling2D(size=(4, 4), interpolation="bilinear")(y3)

    y4 = Conv2D(num_classes, 3, padding="same")(d2)
    y4 = UpSampling2D(size=(8, 8), interpolation="bilinear")(y4)

    y5 = Conv2D(num_classes, 3, padding="same")(d1)
    y5 = UpSampling2D(size=(16, 16), interpolation="bilinear")(y5)

    y6 = Conv2D(num_classes, 3, padding="same")(b1)
    y6 = UpSampling2D(size=(32, 32), interpolation="bilinear")(y6)

    y0 = Concatenate()([y1, y2, y3, y4, y5, y6])
    y0 = Conv2D(num_classes, 3, padding="same")(y0)

    y0 = Activation("sigmoid", name="y0")(y0)
    y1 = Activation("sigmoid", name="y1")(y1)
    y2 = Activation("sigmoid", name="y2")(y2)
    y3 = Activation("sigmoid", name="y3")(y3)
    y4 = Activation("sigmoid", name="y4")(y4)
    y5 = Activation("sigmoid", name="y5")(y5)
    y6 = Activation("sigmoid", name="y6")(y6)

    model = tf.keras.models.Model(inputs, outputs=[y0, y1, y2, y3, y4, y5, y6])
    return model


def build_u2net(input_shape, num_classes=1):
    out_ch = [64, 128, 256, 512, 512, 512, 512, 256, 128, 64, 64]
    int_ch = [32, 32, 64, 128, 256, 256, 256, 128, 64, 32, 16]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model


def build_u2net_lite(input_shape, num_classes=1):
    out_ch = [64, 64, 64, 64, 64, 64, 64, 64, 64, 64, 64]
    int_ch = [16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16]
    model = u2net(input_shape, out_ch, int_ch, num_classes=num_classes)
    return model


if __name__ == "__main__":
    model = build_u2net_lite((512, 512, 3))
    model.summary()


# ...
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 512, 512, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 512, 512, 64)         1792      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 512, 512, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 512, 512, 64)         0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 512, 512, 16)         9232      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 512, 512, 16)         64        ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 512, 512, 16)         0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 256, 256, 16)         0         ['activation_1[0][0]']
#  D)
#
#  conv2d_2 (Conv2D)           (None, 256, 256, 16)         2320      ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 256, 256, 16)         64        ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 256, 256, 16)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 128, 16)         0         ['activation_2[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 16)         2320      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 16)         64        ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 16)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 16)           0         ['activation_3[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 16)           2320      ['max_pooling2d_2[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 64, 16)           64        ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 64, 64, 16)           0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 32, 16)           0         ['activation_4[0][0]']
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 16)           2320      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 16)           64        ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 16)           0         ['activation_5[0][0]']
#  g2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 16)           2320      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 16, 16, 16)           64        ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 16, 16, 16)           0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 16, 16, 16)           2320      ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 16, 16, 16)           64        ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 16, 16, 16)           0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  concatenate (Concatenate)   (None, 16, 16, 32)           0         ['activation_7[0][0]',
#                                                                      'activation_6[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 16)           4624      ['concatenate[0][0]']
#
#  batch_normalization_8 (Bat  (None, 16, 16, 16)           64        ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 16, 16, 16)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  up_sampling2d (UpSampling2  (None, 32, 32, 16)           0         ['activation_8[0][0]']
#  D)
#
#  concatenate_1 (Concatenate  (None, 32, 32, 32)           0         ['up_sampling2d[0][0]',
#  )                                                                   'activation_5[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 16)           4624      ['concatenate_1[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32, 32, 16)           64        ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 32, 32, 16)           0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  up_sampling2d_1 (UpSamplin  (None, 64, 64, 16)           0         ['activation_9[0][0]']
#  g2D)
#
#  concatenate_2 (Concatenate  (None, 64, 64, 32)           0         ['up_sampling2d_1[0][0]',
#  )                                                                   'activation_4[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 64, 64, 16)           4624      ['concatenate_2[0][0]']
#
#  batch_normalization_10 (Ba  (None, 64, 64, 16)           64        ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 64, 64, 16)           0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  up_sampling2d_2 (UpSamplin  (None, 128, 128, 16)         0         ['activation_10[0][0]']
#  g2D)
#
#  concatenate_3 (Concatenate  (None, 128, 128, 32)         0         ['up_sampling2d_2[0][0]',
#  )                                                                   'activation_3[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 16)         4624      ['concatenate_3[0][0]']
#
#  batch_normalization_11 (Ba  (None, 128, 128, 16)         64        ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 128, 128, 16)         0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  up_sampling2d_3 (UpSamplin  (None, 256, 256, 16)         0         ['activation_11[0][0]']
#  g2D)
#
#  concatenate_4 (Concatenate  (None, 256, 256, 32)         0         ['up_sampling2d_3[0][0]',
#  )                                                                   'activation_2[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 256, 256, 16)         4624      ['concatenate_4[0][0]']
#
#  batch_normalization_12 (Ba  (None, 256, 256, 16)         64        ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  up_sampling2d_4 (UpSamplin  (None, 512, 512, 16)         0         ['activation_12[0][0]']
#  g2D)
#
#  concatenate_5 (Concatenate  (None, 512, 512, 32)         0         ['up_sampling2d_4[0][0]',
#  )                                                                   'activation_1[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 512, 512, 64)         18496     ['concatenate_5[0][0]']
#
#  batch_normalization_13 (Ba  (None, 512, 512, 64)         256       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 512, 512, 64)         0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  add (Add)                   (None, 512, 512, 64)         0         ['activation_13[0][0]',
#                                                                      'activation[0][0]']
#
#  max_pooling2d_5 (MaxPoolin  (None, 256, 256, 64)         0         ['add[0][0]']
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 256, 256, 64)         36928     ['max_pooling2d_5[0][0]']
#
#  batch_normalization_14 (Ba  (None, 256, 256, 64)         256       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_14[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 16)         9232      ['activation_14[0][0]']
#
#  batch_normalization_15 (Ba  (None, 256, 256, 16)         64        ['conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 256, 256, 16)         0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  max_pooling2d_6 (MaxPoolin  (None, 128, 128, 16)         0         ['activation_15[0][0]']
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 16)         2320      ['max_pooling2d_6[0][0]']
#
#  batch_normalization_16 (Ba  (None, 128, 128, 16)         64        ['conv2d_16[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 128, 128, 16)         0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  max_pooling2d_7 (MaxPoolin  (None, 64, 64, 16)           0         ['activation_16[0][0]']
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 16)           2320      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_17 (Ba  (None, 64, 64, 16)           64        ['conv2d_17[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 64, 64, 16)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 32, 32, 16)           0         ['activation_17[0][0]']
#  g2D)
#
#  conv2d_18 (Conv2D)          (None, 32, 32, 16)           2320      ['max_pooling2d_8[0][0]']
#
#  batch_normalization_18 (Ba  (None, 32, 32, 16)           64        ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 32, 32, 16)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  max_pooling2d_9 (MaxPoolin  (None, 16, 16, 16)           0         ['activation_18[0][0]']
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 16)           2320      ['max_pooling2d_9[0][0]']
#
#  batch_normalization_19 (Ba  (None, 16, 16, 16)           64        ['conv2d_19[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 16, 16, 16)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 16, 16, 16)           2320      ['activation_19[0][0]']
#
#  batch_normalization_20 (Ba  (None, 16, 16, 16)           64        ['conv2d_20[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 16, 16, 16)           0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  concatenate_6 (Concatenate  (None, 16, 16, 32)           0         ['activation_20[0][0]',
#  )                                                                   'activation_19[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 16, 16, 16)           4624      ['concatenate_6[0][0]']
#
#  batch_normalization_21 (Ba  (None, 16, 16, 16)           64        ['conv2d_21[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 16, 16, 16)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  up_sampling2d_5 (UpSamplin  (None, 32, 32, 16)           0         ['activation_21[0][0]']
#  g2D)
#
#  concatenate_7 (Concatenate  (None, 32, 32, 32)           0         ['up_sampling2d_5[0][0]',
#  )                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 32, 32, 16)           4624      ['concatenate_7[0][0]']
#
#  batch_normalization_22 (Ba  (None, 32, 32, 16)           64        ['conv2d_22[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 32, 32, 16)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  up_sampling2d_6 (UpSamplin  (None, 64, 64, 16)           0         ['activation_22[0][0]']
#  g2D)
#
#  concatenate_8 (Concatenate  (None, 64, 64, 32)           0         ['up_sampling2d_6[0][0]',
#  )                                                                   'activation_17[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 16)           4624      ['concatenate_8[0][0]']
#
#  batch_normalization_23 (Ba  (None, 64, 64, 16)           64        ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 64, 64, 16)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  up_sampling2d_7 (UpSamplin  (None, 128, 128, 16)         0         ['activation_23[0][0]']
#  g2D)
#
#  concatenate_9 (Concatenate  (None, 128, 128, 32)         0         ['up_sampling2d_7[0][0]',
#  )                                                                   'activation_16[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 128, 128, 16)         4624      ['concatenate_9[0][0]']
#
#  batch_normalization_24 (Ba  (None, 128, 128, 16)         64        ['conv2d_24[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 128, 128, 16)         0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  up_sampling2d_8 (UpSamplin  (None, 256, 256, 16)         0         ['activation_24[0][0]']
#  g2D)
#
#  concatenate_10 (Concatenat  (None, 256, 256, 32)         0         ['up_sampling2d_8[0][0]',
#  e)                                                                  'activation_15[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 256, 256, 64)         18496     ['concatenate_10[0][0]']
#
#  batch_normalization_25 (Ba  (None, 256, 256, 64)         256       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 256, 256, 64)         0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  add_1 (Add)                 (None, 256, 256, 64)         0         ['activation_25[0][0]',
#                                                                      'activation_14[0][0]']
#
#  max_pooling2d_10 (MaxPooli  (None, 128, 128, 64)         0         ['add_1[0][0]']
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 128, 128, 64)         36928     ['max_pooling2d_10[0][0]']
#
#  batch_normalization_26 (Ba  (None, 128, 128, 64)         256       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 128, 128, 16)         9232      ['activation_26[0][0]']
#
#  batch_normalization_27 (Ba  (None, 128, 128, 16)         64        ['conv2d_27[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 128, 128, 16)         0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  max_pooling2d_11 (MaxPooli  (None, 64, 64, 16)           0         ['activation_27[0][0]']
#  ng2D)
#
#  conv2d_28 (Conv2D)          (None, 64, 64, 16)           2320      ['max_pooling2d_11[0][0]']
#
#  batch_normalization_28 (Ba  (None, 64, 64, 16)           64        ['conv2d_28[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 64, 64, 16)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  max_pooling2d_12 (MaxPooli  (None, 32, 32, 16)           0         ['activation_28[0][0]']
#  ng2D)
#
#  conv2d_29 (Conv2D)          (None, 32, 32, 16)           2320      ['max_pooling2d_12[0][0]']
#
#  batch_normalization_29 (Ba  (None, 32, 32, 16)           64        ['conv2d_29[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 32, 32, 16)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_13 (MaxPooli  (None, 16, 16, 16)           0         ['activation_29[0][0]']
#  ng2D)
#
#  conv2d_30 (Conv2D)          (None, 16, 16, 16)           2320      ['max_pooling2d_13[0][0]']
#
#  batch_normalization_30 (Ba  (None, 16, 16, 16)           64        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 16, 16, 16)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 16, 16, 16)           2320      ['activation_30[0][0]']
#
#  batch_normalization_31 (Ba  (None, 16, 16, 16)           64        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 16, 16, 16)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  concatenate_11 (Concatenat  (None, 16, 16, 32)           0         ['activation_31[0][0]',
#  e)                                                                  'activation_30[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 16, 16, 16)           4624      ['concatenate_11[0][0]']
#
#  batch_normalization_32 (Ba  (None, 16, 16, 16)           64        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 16, 16, 16)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  up_sampling2d_9 (UpSamplin  (None, 32, 32, 16)           0         ['activation_32[0][0]']
#  g2D)
#
#  concatenate_12 (Concatenat  (None, 32, 32, 32)           0         ['up_sampling2d_9[0][0]',
#  e)                                                                  'activation_29[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 32, 32, 16)           4624      ['concatenate_12[0][0]']
#
#  batch_normalization_33 (Ba  (None, 32, 32, 16)           64        ['conv2d_33[0][0]']
#  tchNormalization)
#
#  activation_33 (Activation)  (None, 32, 32, 16)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  up_sampling2d_10 (UpSampli  (None, 64, 64, 16)           0         ['activation_33[0][0]']
#  ng2D)
#
#  concatenate_13 (Concatenat  (None, 64, 64, 32)           0         ['up_sampling2d_10[0][0]',
#  e)                                                                  'activation_28[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 64, 64, 16)           4624      ['concatenate_13[0][0]']
#
#  batch_normalization_34 (Ba  (None, 64, 64, 16)           64        ['conv2d_34[0][0]']
#  tchNormalization)
#
#  activation_34 (Activation)  (None, 64, 64, 16)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  up_sampling2d_11 (UpSampli  (None, 128, 128, 16)         0         ['activation_34[0][0]']
#  ng2D)
#
#  concatenate_14 (Concatenat  (None, 128, 128, 32)         0         ['up_sampling2d_11[0][0]',
#  e)                                                                  'activation_27[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 128, 128, 64)         18496     ['concatenate_14[0][0]']
#
#  batch_normalization_35 (Ba  (None, 128, 128, 64)         256       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_35 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 128, 128, 64)         0         ['activation_35[0][0]',
#                                                                      'activation_26[0][0]']
#
#  max_pooling2d_14 (MaxPooli  (None, 64, 64, 64)           0         ['add_2[0][0]']
#  ng2D)
#
#  conv2d_36 (Conv2D)          (None, 64, 64, 64)           36928     ['max_pooling2d_14[0][0]']
#
#  batch_normalization_36 (Ba  (None, 64, 64, 64)           256       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_36 (Activation)  (None, 64, 64, 64)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 64, 64, 16)           9232      ['activation_36[0][0]']
#
#  batch_normalization_37 (Ba  (None, 64, 64, 16)           64        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  activation_37 (Activation)  (None, 64, 64, 16)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  max_pooling2d_15 (MaxPooli  (None, 32, 32, 16)           0         ['activation_37[0][0]']
#  ng2D)
#
#  conv2d_38 (Conv2D)          (None, 32, 32, 16)           2320      ['max_pooling2d_15[0][0]']
#
#  batch_normalization_38 (Ba  (None, 32, 32, 16)           64        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  activation_38 (Activation)  (None, 32, 32, 16)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  max_pooling2d_16 (MaxPooli  (None, 16, 16, 16)           0         ['activation_38[0][0]']
#  ng2D)
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 16)           2320      ['max_pooling2d_16[0][0]']
#
#  batch_normalization_39 (Ba  (None, 16, 16, 16)           64        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  activation_39 (Activation)  (None, 16, 16, 16)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 16, 16, 16)           2320      ['activation_39[0][0]']
#
#  batch_normalization_40 (Ba  (None, 16, 16, 16)           64        ['conv2d_40[0][0]']
#  tchNormalization)
#
#  activation_40 (Activation)  (None, 16, 16, 16)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  concatenate_15 (Concatenat  (None, 16, 16, 32)           0         ['activation_40[0][0]',
#  e)                                                                  'activation_39[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 16, 16, 16)           4624      ['concatenate_15[0][0]']
#
#  batch_normalization_41 (Ba  (None, 16, 16, 16)           64        ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_41 (Activation)  (None, 16, 16, 16)           0         ['batch_normalization_41[0][0]
# ...
#  atchNormalization)
#
#  activation_103 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  max_pooling2d_32 (MaxPooli  (None, 16, 16, 16)           0         ['activation_103[0][0]']
#  ng2D)
#
#  conv2d_104 (Conv2D)         (None, 16, 16, 16)           2320      ['max_pooling2d_32[0][0]']
#
#  batch_normalization_104 (B  (None, 16, 16, 16)           64        ['conv2d_104[0][0]']
#  atchNormalization)
#
#  activation_104 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  conv2d_105 (Conv2D)         (None, 16, 16, 16)           2320      ['activation_104[0][0]']
#
#  batch_normalization_105 (B  (None, 16, 16, 16)           64        ['conv2d_105[0][0]']
#  atchNormalization)
#
#  activation_105 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_105[0][0
#  )                                                                  ]']
#
#  concatenate_44 (Concatenat  (None, 16, 16, 32)           0         ['activation_105[0][0]',
#  e)                                                                  'activation_104[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 16, 16, 16)           4624      ['concatenate_44[0][0]']
#
#  batch_normalization_106 (B  (None, 16, 16, 16)           64        ['conv2d_106[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, 16, 16, 16)           0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  up_sampling2d_28 (UpSampli  (None, 32, 32, 16)           0         ['activation_106[0][0]']
#  ng2D)
#
#  concatenate_45 (Concatenat  (None, 32, 32, 32)           0         ['up_sampling2d_28[0][0]',
#  e)                                                                  'activation_103[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 32, 32, 16)           4624      ['concatenate_45[0][0]']
#
#  batch_normalization_107 (B  (None, 32, 32, 16)           64        ['conv2d_107[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 32, 32, 16)           0         ['batch_normalization_107[0][0
#  )                                                                  ]']
#
#  up_sampling2d_29 (UpSampli  (None, 64, 64, 16)           0         ['activation_107[0][0]']
#  ng2D)
#
#  concatenate_46 (Concatenat  (None, 64, 64, 32)           0         ['up_sampling2d_29[0][0]',
#  e)                                                                  'activation_102[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 64, 64, 16)           4624      ['concatenate_46[0][0]']
#
#  batch_normalization_108 (B  (None, 64, 64, 16)           64        ['conv2d_108[0][0]']
#  atchNormalization)
#
#  activation_108 (Activation  (None, 64, 64, 16)           0         ['batch_normalization_108[0][0
#  )                                                                  ]']
#
#  up_sampling2d_30 (UpSampli  (None, 128, 128, 16)         0         ['activation_108[0][0]']
#  ng2D)
#
#  concatenate_47 (Concatenat  (None, 128, 128, 32)         0         ['up_sampling2d_30[0][0]',
#  e)                                                                  'activation_101[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 128, 128, 16)         4624      ['concatenate_47[0][0]']
#
#  batch_normalization_109 (B  (None, 128, 128, 16)         64        ['conv2d_109[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, 128, 128, 16)         0         ['batch_normalization_109[0][0
#  )                                                                  ]']
#
#  up_sampling2d_31 (UpSampli  (None, 256, 256, 16)         0         ['activation_109[0][0]']
#  ng2D)
#
#  concatenate_48 (Concatenat  (None, 256, 256, 32)         0         ['up_sampling2d_31[0][0]',
#  e)                                                                  'activation_100[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 256, 256, 16)         4624      ['concatenate_48[0][0]']
#
#  batch_normalization_110 (B  (None, 256, 256, 16)         64        ['conv2d_110[0][0]']
#  atchNormalization)
#
#  activation_110 (Activation  (None, 256, 256, 16)         0         ['batch_normalization_110[0][0
#  )                                                                  ]']
#
#  up_sampling2d_32 (UpSampli  (None, 512, 512, 16)         0         ['activation_110[0][0]']
#  ng2D)
#
#  concatenate_49 (Concatenat  (None, 512, 512, 32)         0         ['up_sampling2d_32[0][0]',
#  e)                                                                  'activation_99[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 512, 512, 64)         18496     ['concatenate_49[0][0]']
#
#  batch_normalization_111 (B  (None, 512, 512, 64)         256       ['conv2d_111[0][0]']
#  atchNormalization)
#
#  activation_111 (Activation  (None, 512, 512, 64)         0         ['batch_normalization_111[0][0
#  )                                                                  ]']
#
#  add_10 (Add)                (None, 512, 512, 64)         0         ['activation_111[0][0]',
#                                                                      'activation_98[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 256, 256, 1)          577       ['add_9[0][0]']
#
#  conv2d_114 (Conv2D)         (None, 128, 128, 1)          577       ['add_8[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 64, 64, 1)            577       ['add_7[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 32, 32, 1)            577       ['add_6[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 16, 16, 1)            577       ['add_5[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 512, 512, 1)          577       ['add_10[0][0]']
#
#  up_sampling2d_33 (UpSampli  (None, 512, 512, 1)          0         ['conv2d_113[0][0]']
#  ng2D)
#
#  up_sampling2d_34 (UpSampli  (None, 512, 512, 1)          0         ['conv2d_114[0][0]']
#  ng2D)
#
#  up_sampling2d_35 (UpSampli  (None, 512, 512, 1)          0         ['conv2d_115[0][0]']
#  ng2D)
#
#  up_sampling2d_36 (UpSampli  (None, 512, 512, 1)          0         ['conv2d_116[0][0]']
#  ng2D)
#
#  up_sampling2d_37 (UpSampli  (None, 512, 512, 1)          0         ['conv2d_117[0][0]']
#  ng2D)
#
#  concatenate_50 (Concatenat  (None, 512, 512, 6)          0         ['conv2d_112[0][0]',
#  e)                                                                  'up_sampling2d_33[0][0]',
#                                                                      'up_sampling2d_34[0][0]',
#                                                                      'up_sampling2d_35[0][0]',
#                                                                      'up_sampling2d_36[0][0]',
#                                                                      'up_sampling2d_37[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 512, 512, 1)          55        ['concatenate_50[0][0]']
#
#  y0 (Activation)             (None, 512, 512, 1)          0         ['conv2d_118[0][0]']
#
#  y1 (Activation)             (None, 512, 512, 1)          0         ['conv2d_112[0][0]']
#
#  y2 (Activation)             (None, 512, 512, 1)          0         ['up_sampling2d_33[0][0]']
#
#  y3 (Activation)             (None, 512, 512, 1)          0         ['up_sampling2d_34[0][0]']
#
#  y4 (Activation)             (None, 512, 512, 1)          0         ['up_sampling2d_35[0][0]']
#
#  y5 (Activation)             (None, 512, 512, 1)          0         ['up_sampling2d_36[0][0]']
#
#  y6 (Activation)             (None, 512, 512, 1)          0         ['up_sampling2d_37[0][0]']
#
# ==================================================================================================
# Total params: 1136925 (4.34 MB)
# Trainable params: 1131229 (4.32 MB)
# Non-trainable params: 5696 (22.25 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# **Let us now train the model**

# %%
# from model import build_u2net_lite, build_u2net
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, ReduceLROnPlateau, EarlyStopping, TensorBoard
import tensorflow as tf
from sklearn.utils import shuffle
from glob import glob
import cv2
import numpy as np
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"


""" Global parameters """

# may need to change the below size of image based on GPU capacity
H = 128
W = 128


def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)


def load_dataset(path, split=0.1):
    train_x = sorted(
        glob(os.path.join(path, "train", "blurred_image", "*.jpg")))
    train_y = sorted(glob(os.path.join(path, "train", "mask", "*.png")))

    valid_x = sorted(glob(os.path.join(path, "validation",
                     "P3M-500-NP", "original_image", "*.jpg")))
    valid_y = sorted(
        glob(os.path.join(path, "validation", "P3M-500-NP", "mask", "*.png")))

    return (train_x, train_y), (valid_x, valid_y)


def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    return x


def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    x = cv2.resize(x, (W, H))
    x = x / 255.0
    x = x.astype(np.float32)
    x = np.expand_dims(x, axis=-1)
    return x


def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([H, W, 3])
    y.set_shape([H, W, 1])
    return x, y


def tf_dataset(X, Y, batch=2):
    ds = tf.data.Dataset.from_tensor_slices((X, Y))
    ds = ds.map(tf_parse).batch(batch).prefetch(10)
    return ds


if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)
    files="/kaggle/working/files"

    """ Directory for storing files """
    create_dir(files)

    """ Hyperparameters """
    # may need to change the below parameters(esp. batch size) based on GPU capacity
    batch_size = 4
    lr = 1e-4
    num_epochs = 2
    model_path = os.path.join(files, "model2.h5")
    csv_path = os.path.join(files, "log.csv")

    """ Dataset """
    # dataset_path = "P3M-10k"
    dataset_path = "/kaggle/input/p3mzip/P3M-10k"
    (train_x, train_y), (valid_x, valid_y) = load_dataset(dataset_path)

    print(f"Train: {len(train_x)} - {len(train_y)}")
    print(f"Valid: {len(valid_x)} - {len(valid_y)}")

    train_dataset = tf_dataset(train_x, train_y, batch=batch_size)
    valid_dataset = tf_dataset(valid_x, valid_y, batch=batch_size)

    """ Model """
    model = build_u2net((H, W, 3))
    # model.load_weights(model_path)
    # model.compile(loss="binary_crossentropy", optimizer=Adam(lr))
    model.compile(loss="binary_crossentropy",
                  optimizer=Adam(lr), run_eagerly=True)

    callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                          patience=5, min_lr=1e-7, verbose=1),
        CSVLogger(csv_path),
        EarlyStopping(monitor='val_loss', patience=20,
                      restore_best_weights=False),
    ]

    model.fit(
        train_dataset,
        epochs=num_epochs,
        validation_data=valid_dataset,
        callbacks=callbacks
    )
    # print("Training code done")
# Out:
# Train: 9421 - 9421
# Valid: 500 - 500
# Epoch 1/2
# 2356/2356 [==============================] - ETA: 0s - loss: 1.7895 - y0_loss: 0.2445 - y1_loss: 0.2436 - y2_loss: 0.2403 - y3_loss: 0.2436 - y4_loss: 0.2477 - y5_loss: 0.2672 - y6_loss: 0.3026
# Epoch 1: val_loss improved from inf to 1.37008, saving model to /kaggle/working/files/model2.h5
# /opt/conda/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 2356/2356 [==============================] - 2336s 963ms/step - loss: 1.7895 - y0_loss: 0.2445 - y1_loss: 0.2436 - y2_loss: 0.2403 - y3_loss: 0.2436 - y4_loss: 0.2477 - y5_loss: 0.2672 - y6_loss: 0.3026 - val_loss: 1.3701 - val_y0_loss: 0.1739 - val_y1_loss: 0.1715 - val_y2_loss: 0.1771 - val_y3_loss: 0.1860 - val_y4_loss: 0.1901 - val_y5_loss: 0.2064 - val_y6_loss: 0.2651 - lr: 1.0000e-04
# Epoch 2/2
# 2356/2356 [==============================] - ETA: 0s - loss: 1.1341 - y0_loss: 0.1436 - y1_loss: 0.1425 - y2_loss: 0.1433 - y3_loss: 0.1489 - y4_loss: 0.1567 - y5_loss: 0.1756 - y6_loss: 0.2234
# Epoch 2: val_loss improved from 1.37008 to 1.12853, saving model to /kaggle/working/files/model2.h5
# 2356/2356 [==============================] - 2269s 963ms/step - loss: 1.1341 - y0_loss: 0.1436 - y1_loss: 0.1425 - y2_loss: 0.1433 - y3_loss: 0.1489 - y4_loss: 0.1567 - y5_loss: 0.1756 - y6_loss: 0.2234 - val_loss: 1.1285 - val_y0_loss: 0.1387 - val_y1_loss: 0.1391 - val_y2_loss: 0.1408 - val_y3_loss: 0.1450 - val_y4_loss: 0.1561 - val_y5_loss: 0.1758 - val_y6_loss: 0.2330 - lr: 1.0000e-04
# Training code done

# %%
# def load_dataset(path, split=0.1):
#     train_x = sorted(
#         glob(os.path.join(path, "train", "blurred_image", "*.jpg")))
#     train_y = sorted(glob(os.path.join(path, "train", "mask", "*.png")))

#     valid_x = sorted(glob(os.path.join(path, "validation",
#                      "P3M-500-NP", "original_image", "*.jpg")))
#     valid_y = sorted(
#         glob(os.path.join(path, "validation", "P3M-500-NP", "mask", "*.png")))

#     return (train_x, train_y), (valid_x, valid_y)

# %% [markdown]
# **Let us now test the model**

# %%
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import numpy as np
import cv2
import pandas as pd
from glob import glob
from tqdm import tqdm
import tensorflow as tf
# from train import load_dataset

""" Global parameters """
H = 128
W = 128

""" Creating a directory """
def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

if __name__ == "__main__":
    """ Seeding """
    np.random.seed(42)
    tf.random.set_seed(42)
    
    """ Load the model """
    files="/kaggle/working/files"
    model_path = os.path.join(files, "model2.h5")
    model = tf.keras.models.load_model(model_path)

    """ Directory for storing files """
    results="/kaggle/working/results"
    for item in ["joint", "mask"]:
        create_dir(f"{results}/{item}")

    """ Dataset """
    images = glob("/kaggle/input/git-repo/U2-Net-for-Image-Matting-in-TensorFlow-main/test/*")
    print(f"Images: {len(images)}")

    """ Prediction """
    for x in tqdm(images, total=len(images)):
        """ Extracting the name """
        name = x.split("/")[-1]

        """ Reading the image """
        image = cv2.imread(x, cv2.IMREAD_COLOR)
        x = cv2.resize(image, (W, H))
        x = x/255.0
        x = np.expand_dims(x, axis=0)

        """ Prediction """
        pred = model.predict(x, verbose=0)

        line = np.ones((H, 10, 3)) * 255

        """ Joint and save mask """
        pred_list = []
        for item in pred:
            p = item[0] * 255
            p = np.concatenate([p, p, p], axis=-1)

            pred_list.append(p)
            pred_list.append(line)

        save_image_path = os.path.join(results, "mask", name)
        cat_images = np.concatenate(pred_list, axis=1)
        cv2.imwrite(save_image_path, cat_images)

        """ Save final mask """
        image_h, image_w, _ = image.shape

        y0 = pred[0][0]
        y0 = cv2.resize(y0, (image_w, image_h))
        y0 = np.expand_dims(y0, axis=-1)
        y0 = np.concatenate([y0, y0, y0], axis=-1)

        line = line = np.ones((image_h, 10, 3)) * 255

        cat_images = np.concatenate([image, line, y0*255, line, image*y0], axis=1)
        save_image_path = os.path.join(results, "joint", name)
        cv2.imwrite(save_image_path, cat_images)
# Out:
# Images: 19
# 100%|██████████| 19/19 [00:14<00:00,  1.30it/s]

# %%
# Copy the folder
# !cp -r /kaggle/working/results /kaggle/working/result1

# Create a zip archive of the copied folder

# %%
# !zip -r /kaggle/working/result2.zip /kaggle/working/result1
# Out:
#   adding: kaggle/working/result1/ (stored 0%)
#   adding: kaggle/working/result1/joint/ (stored 0%)
#   adding: kaggle/working/result1/joint/photo-1599566150163-29194dcaad36.jpg (deflated 5%)
#   adding: kaggle/working/result1/joint/photo-1473830394358-91588751b241.jpg (deflated 18%)
#   adding: kaggle/working/result1/joint/photo-1544005313-94ddf0286df2.jpg (deflated 3%)
#   adding: kaggle/working/result1/joint/photo-1500648767791-00dcc994a43e.jpg (deflated 3%)
#   adding: kaggle/working/result1/joint/photo-1494790108377-be9c29b29330.jpg (deflated 11%)
#   adding: kaggle/working/result1/joint/photo-1554151228-14d9def656e4.jpg (deflated 1%)
#   adding: kaggle/working/result1/joint/photo-1547425260-76bcadfb4f2c.jpg (deflated 7%)
#   adding: kaggle/working/result1/joint/photo-1438761681033-6461ffad8d80.jpg (deflated 11%)
#   adding: kaggle/working/result1/joint/photo-1552058544-f2b08422138a.jpg (deflated 5%)
#   adding: kaggle/working/result1/joint/photo-1554727242-741c14fa561c.jpg (deflated 3%)
#   adding: kaggle/working/result1/joint/photo-1491349174775-aaafddd81942.jpg (deflated 1%)
#   adding: kaggle/working/result1/joint/photo-1567532939604-b6b5b0db2604.jpg (deflated 8%)
#   adding: kaggle/working/result1/joint/photo-1544723795-3fb6469f5b39.jpg (deflated 8%)
#   adding: kaggle/working/result1/joint/photo-1499952127939-9bbf5af6c51c.jpg (deflated 6%)
#   adding: kaggle/working/result1/joint/photo-1573140247632-f8fd74997d5c.jpg (deflated 7%)
#   adding: kaggle/working/result1/joint/photo-1503249023995-51b0f3778ccf.jpg (deflated 8%)
#   adding: kaggle/working/result1/joint/photo-1542206395-9feb3edaa68d.jpg (deflated 3%)
#   adding: kaggle/working/result1/joint/photo-1593104547489-5cfb3839a3b5.jpg (deflated 8%)
#   adding: kaggle/working/result1/joint/photo-1503023345310-bd7c1de61c7d.jpg (deflated 9%)
#   adding: kaggle/working/result1/mask/ (stored 0%)
#   adding: kaggle/working/result1/mask/photo-1599566150163-29194dcaad36.jpg (deflated 4%)
#   adding: kaggle/working/result1/mask/photo-1473830394358-91588751b241.jpg (deflated 5%)
#   adding: kaggle/working/result1/mask/photo-1544005313-94ddf0286df2.jpg (deflated 3%)
#   adding: kaggle/working/result1/mask/photo-1500648767791-00dcc994a43e.jpg (deflated 3%)
#   adding: kaggle/working/result1/mask/photo-1494790108377-be9c29b29330.jpg (deflated 5%)
#   adding: kaggle/working/result1/mask/photo-1554151228-14d9def656e4.jpg (deflated 2%)
#   adding: kaggle/working/result1/mask/photo-1547425260-76bcadfb4f2c.jpg (deflated 6%)
#   adding: kaggle/working/result1/mask/photo-1438761681033-6461ffad8d80.jpg (deflated 9%)
#   adding: kaggle/working/result1/mask/photo-1552058544-f2b08422138a.jpg (deflated 4%)
#   adding: kaggle/working/result1/mask/photo-1554727242-741c14fa561c.jpg (deflated 2%)
#   adding: kaggle/working/result1/mask/photo-1491349174775-aaafddd81942.jpg (deflated 2%)
#   adding: kaggle/working/result1/mask/photo-1567532939604-b6b5b0db2604.jpg (deflated 9%)
#   adding: kaggle/working/result1/mask/photo-1544723795-3fb6469f5b39.jpg (deflated 4%)
#   adding: kaggle/working/result1/mask/photo-1499952127939-9bbf5af6c51c.jpg (deflated 8%)
#   adding: kaggle/working/result1/mask/photo-1573140247632-f8fd74997d5c.jpg (deflated 6%)
#   adding: kaggle/working/result1/mask/photo-1503249023995-51b0f3778ccf.jpg (deflated 4%)
#   adding: kaggle/working/result1/mask/photo-1542206395-9feb3edaa68d.jpg (deflated 2%)
#   adding: kaggle/working/result1/mask/photo-1593104547489-5cfb3839a3b5.jpg (deflated 10%)
#   adding: kaggle/working/result1/mask/photo-1503023345310-bd7c1de61c7d.jpg (deflated 9%)
